# %% [markdown]
# <a href="https://colab.research.google.com/github/anooj1483/news_classifier_ai/blob/master/News_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
news_data = pd.read_csv('news-headline-dataset.csv')

# %%
news_data.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# ...

# %%
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   link               19999 non-null  object
#  1   headline           19999 non-null  object
#  2   category           19999 non-null  object
#  3   short_description  19999 non-null  object
#  4   authors            18904 non-null  object
#  5   date               19999 non-null  object
# dtypes: object(6)
# memory usage: 937.6+ KB

# %% [markdown]
# # Drop Columns

# %%
news_data.drop('link', axis=1, inplace=True)

# %%
news_data.drop('authors', axis=1, inplace=True)

# %%
news_data.drop('date', axis=1, inplace=True)

# %%
news_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19999 entries, 0 to 19998
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   headline           19999 non-null  object
#  1   category           19999 non-null  object
#  2   short_description  19999 non-null  object
# dtypes: object(3)
# memory usage: 468.9+ KB

# %% [markdown]
# # Check Null

# %%
news_data.headline.isnull().sum()
# Out:
# 0

# %%
news_data.category.isnull().sum()
# Out:
# 0

# %%
news_data.short_description.isnull().sum()
# Out:
# 0

# %%
news_data.iloc[:, 0].str.strip() == ''
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19994    False
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# Name: headline, Length: 19999, dtype: bool

# %%
(news_data.iloc[:, 0].str.strip() == '').sum()
# Out:
# 0

# %%
news_data.iloc[:, 1].str.strip() == ''
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19994    False
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# Name: category, Length: 19999, dtype: bool

# %%
(news_data.iloc[:, 1].str.strip() == '').sum()
# Out:
# 0

# %%
news_data.iloc[:, 2].str.strip() == ''
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19994    False
# 19995    False
# 19996    False
# 19997    False
# 19998    False
# Name: short_description, Length: 19999, dtype: bool

# %%
(news_data.iloc[:, 2].str.strip() == '').sum()
# Out:
# 0

# %% [markdown]
# # Checking Categories

# %%
news_data.category.describe()
# Out:
# count        19999
# unique          36
# top       POLITICS
# freq          6932
# Name: category, dtype: object

# %%
news_data['category'].unique()
# Out:
# array(['U.S. NEWS', 'COMEDY', 'PARENTING', 'WORLD NEWS', 'CULTURE & ARTS',
#        'TECH', 'SPORTS', 'ENTERTAINMENT', 'POLITICS', 'WEIRD NEWS',
#        'ENVIRONMENT', 'EDUCATION', 'CRIME', 'SCIENCE', 'WELLNESS',
#        'BUSINESS', 'STYLE & BEAUTY', 'FOOD & DRINK', 'MEDIA',
#        'QUEER VOICES', 'HOME & LIVING', 'WOMEN', 'BLACK VOICES', 'TRAVEL',
#        'MONEY', 'RELIGION', 'LATINO VOICES', 'IMPACT', 'WEDDINGS',
#        'COLLEGE', 'PARENTS', 'ARTS & CULTURE', 'STYLE', 'GREEN', 'TASTE',
#        'HEALTHY LIVING'], dtype=object)

# %%
news_data.category.value_counts()
# Out:
# POLITICS          6932
# ENTERTAINMENT     3373
# WORLD NEWS        1917
# U.S. NEWS         1377
# COMEDY             782
# QUEER VOICES       608
# SPORTS             590
# BLACK VOICES       531
# MEDIA              512
# WOMEN              407
# WEIRD NEWS         383
# CRIME              377
# BUSINESS           188
# STYLE & BEAUTY     165
# IMPACT             140
# HOME & LIVING      125
# LATINO VOICES      121
# ENVIRONMENT        121
# WELLNESS           118
# PARENTING          114
# FOOD & DRINK       114
# RELIGION           110
# PARENTS            105
# TRAVEL             103
# STYLE               99
# TECH                95
# GREEN               90
# HEALTHY LIVING      86
# SCIENCE             76
# EDUCATION           58
# MONEY               49
# CULTURE & ARTS      44
# TASTE               44
# ARTS & CULTURE      40
# COLLEGE              3
# WEDDINGS             2
# Name: category, dtype: int64

# %%
# news_data[news_data['category'].isin(['GREEN'])]

# %% [markdown]
# # Reducing Categories

# %%
news_data['category']=news_data['category'].replace(['COMEDY'],'ENTERTAINMENT')

# %%
news_data['category']=news_data['category'].replace(['MEDIA','WEIRD NEWS', 'IMPACT'],'WORLD NEWS')

# %%
news_data['category']=news_data['category'].replace(['QUEER VOICES','BLACK VOICES', 'LATINO VOICES'],'COMMUNITY VOICES')

# %%
news_data['category']=news_data['category'].replace(['BUSINESS','MONEY'],'BUSINESS & FINANCE')

# %%
news_data['category']=news_data['category'].replace(['STYLE'],'STYLE & BEAUTY')

# %%
news_data['category']=news_data['category'].replace(['HEALTHY LIVING','WEDDINGS', 'WELLNESS'],'HOME & LIVING')

# %%
news_data['category']=news_data['category'].replace(['GREEN'],'ENVIRONMENT')

# %%
news_data['category']=news_data['category'].replace(['PARENTS'],'PARENTING')

# %%
news_data['category']=news_data['category'].replace(['TASTE'],'FOOD & DRINK')

# %%
news_data['category']=news_data['category'].replace(['TECH', 'SCIENCE'],'TECH & SCIENCE')

# %%
news_data['category']=news_data['category'].replace(['COLLEGE'],'EDUCATION')

# %%
news_data['category']=news_data['category'].replace(['CULTURE & ARTS'],'ARTS & CULTURE')

# %%
news_data.category.value_counts()
# Out:
# POLITICS              6932
# ENTERTAINMENT         4155
# WORLD NEWS            2952
# U.S. NEWS             1377
# COMMUNITY VOICES      1260
# SPORTS                 590
# WOMEN                  407
# CRIME                  377
# HOME & LIVING          331
# STYLE & BEAUTY         264
# BUSINESS & FINANCE     237
# PARENTING              219
# ENVIRONMENT            211
# TECH & SCIENCE         171
# FOOD & DRINK           158
# RELIGION               110
# TRAVEL                 103
# ARTS & CULTURE          84
# EDUCATION               61
# Name: category, dtype: int64

# %% [markdown]
# # Handling Duplicates

# %%
news_data[news_data.headline.duplicated()]
# Out:
#                                                 headline       category  \
# 5226     Netanyahu Holds Solid Lead In Israeli Elections     WORLD NEWS
# 6192   Robert Mugabe, Zimbabwe’s First Post-Independe...     WORLD NEWS
# 8239   What To Watch On Amazon Prime That’s New This ...  ENTERTAINMENT
# 8270          What To Watch On Hulu That’s New This Week  ENTERTAINMENT
# 8301   What To Watch On Amazon Prime That’s New This ...  ENTERTAINMENT
# ...                                                  ...            ...
# 19188  The 'Alt-Lite' White House Reporter Who Got Ar...       POLITICS
# 19274        The 20 Funniest Tweets From Women This Week          WOMEN
# 19756  The Best Chance To Defeat Roy Moore May Be For...       POLITICS
# 19764  The Republican Tax Agenda Has A 'Not Quite' Pr...       POLITICS
# 19765        The 20 Funniest Tweets From Women This Week          WOMEN
#
#                                        short_description
# ...

# %%
news_data = news_data.drop_duplicates(subset=['headline'], keep='first')

# %%
news_data[news_data.headline.duplicated()]
# Out:
# Empty DataFrame
# Columns: [headline, category, short_description]
# Index: []

# %%
news_data[news_data.short_description.duplicated()]
# Out:
#                                                 headline          category  \
# 1444   New On Netflix January 2022: 'Ozark,' 'Phantom...     HOME & LIVING
# 1806   New On Netflix November 2021: 'Big Mouth,' 'Ti...     HOME & LIVING
# 9419   'Dogs May Help Prepare You For Babies, But Cat...        WORLD NEWS
# 9810   'Dogs Protect Humans From Other Humans. Humans...        WORLD NEWS
# 10222                Pets Are 'The 1 Percent' Of Animals        WORLD NEWS
# 10606  Conspiracy Theory Believers Are The Most Skept...        WORLD NEWS
# 10825  Sophie Turner Explains Why Her Engagement To J...     ENTERTAINMENT
# 10996  How China And The U.S. Are Spawning A New Grea...          POLITICS
# 11385  ‘In A Dogs' World, Humans Are Elves That Routi...        WORLD NEWS
# 11685  Watch James Corden Get Smashed In The Face By ...     ENTERTAINMENT
# 11735                              'The Early Worm Dies'        WORLD NEWS
# ...

# %%
news_data = news_data.drop_duplicates(subset=['short_description'], keep='first')

# %%
news_data[news_data.short_description.duplicated()]
# Out:
# Empty DataFrame
# Columns: [headline, category, short_description]
# Index: []

# %%
news_data.category.value_counts()
# Out:
# POLITICS              6917
# ENTERTAINMENT         4108
# WORLD NEWS            2927
# U.S. NEWS             1377
# COMMUNITY VOICES      1257
# SPORTS                 588
# WOMEN                  383
# CRIME                  375
# HOME & LIVING          329
# STYLE & BEAUTY         262
# BUSINESS & FINANCE     237
# PARENTING              214
# ENVIRONMENT            210
# TECH & SCIENCE         171
# FOOD & DRINK           158
# RELIGION               110
# TRAVEL                 103
# ARTS & CULTURE          83
# EDUCATION               61
# Name: category, dtype: int64

# %%
column_values = set(news_data['headline'].values).intersection(set(news_data['short_description'].values))
column_values
# Out:
# set()

# %% [markdown]
# # Merge columns

# %%
news_data['news_description']=news_data['headline'] + " " + news_data['short_description']

# %%
news_data.head()
# Out:
#                                             headline       category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...      U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...      U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...  ENTERTAINMENT
# 3  The Funniest Tweets From Parents This Week (Se...      PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...      U.S. NEWS
#
#                                    short_description  \
# 0  Health experts said it is too early to predict...
# 1  He was subdued by passengers and crew when he ...
# 2  "Until you have a dog you don't understand wha...
# 3  "Accidentally put grown-up toothpaste on my to...
# 4  Amy Cooper accused investment firm Franklin Te...
#
#                                     news_description
# 0  Over 4 Million Americans Roll Up Sleeves For O...
# 1  American Airlines Flyer Charged, Banned For Li...
# 2  23 Of The Funniest Tweets About Cats And Dogs ...
# ...

# %% [markdown]
# # Drop Columns

# %%
news_data.drop('headline', axis=1, inplace=True)

# %%
news_data.drop('short_description', axis=1, inplace=True)

# %%
news_data.head()
# Out:
#         category                                   news_description
# 0      U.S. NEWS  Over 4 Million Americans Roll Up Sleeves For O...
# 1      U.S. NEWS  American Airlines Flyer Charged, Banned For Li...
# 2  ENTERTAINMENT  23 Of The Funniest Tweets About Cats And Dogs ...
# 3      PARENTING  The Funniest Tweets From Parents This Week (Se...
# 4      U.S. NEWS  Woman Who Called Cops On Black Bird-Watcher Lo...

# %% [markdown]
# # Model Training Testing

# %%
X = news_data['news_description']
y = news_data['category']

# %%
import sklearn
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 90)
print(X_train.shape)
print(X_test.shape)
# Out:
# (13909,)
# (5961,)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

from sklearn.pipeline import Pipeline
lr = Pipeline([('tfidf', TfidfVectorizer()),('clf', LogisticRegression(max_iter = 1000)),])

# Train the logistic regression model on the training set
lr.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('clf', LogisticRegression(max_iter=1000))])

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
# Calculate the accuracy of the model
print(f"Accuracy is: {accuracy_score(y_pred,y_test)}")
# Out:
# Accuracy is: 0.6512330145948666

# %% [markdown]
# # Predict

# %%
news = ["Biden to Sign Executive Order That Aims to Make Child Care Cheaper",
       "Google Stock Loses $57 Billion Amid Microsoft's AI 'Lead'—And Reports It Could Be Replaced By Bing On Some Smartphones",
       "Poland suspends food imports from Ukraine to assist its farmers",
       "Can AI Solve The Air Traffic Control Problem? Let's Find Out",
       "Woman From Odisha Runs 42.5 KM In UK Marathon Wearing A Saree",
       "Hillary Clinton: Trump cannot win the election - but Biden will",
       "Jennifer Aniston and Adam Sandler starrer movie 'Murder Mystery 2' got released on March 24, this year",

        "Donald Trump against Obama on Israel war",
        "Kim Kadarshian is all against Kanye West"

        ]

predicted = lr.predict(news)

for doc, category in zip(news, predicted):
     print(category)
# Out:
# POLITICS
# ENTERTAINMENT
# WORLD NEWS
# WORLD NEWS
# WORLD NEWS
# POLITICS
# ENTERTAINMENT
# POLITICS
# ENTERTAINMENT
